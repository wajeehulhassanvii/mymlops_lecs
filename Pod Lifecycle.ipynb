# %% [markdown]
# ![Screenshot%20from%202020-07-15%2003-46-07.png](attachment:Screenshot%20from%202020-07-15%2003-46-07.png)

# %% [markdown]
# ## DEMO

# %% [markdown]
# ![Screenshot%20from%202020-07-15%2003-58-53.png](attachment:Screenshot%20from%202020-07-15%2003-58-53.png)

# %% [markdown]
# we can see that in configuration, we can have a different initContainerm then we can have containers with livenessProbe, readinessProbe, lfeCycle(lifecycle will have preStart, postStart)
