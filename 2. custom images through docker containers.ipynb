# %% [markdown]
# busybox and hello-world were created by someoine else

# %% [markdown]
# **Dockerfile**  is configuration to define how our containers should behave

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### STEPS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### CREATING REDIS SERVER

# %% [markdown]
# ##### FROM alpine - alpine is image specially for docker

# %% [markdown]
# download the dependencies<br>
# RUN apk add --update redis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### docker build .
# will build the docker configurtation image

# %% [markdown]
# then do docker ps to get the docker image id, then do docker run (container id)

# %% [markdown]
# ### how docker works

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### alpine is useful for docker, alpine usually have all the important tools and programs for docker

# %% [markdown]
# ### docker build .

# %% [markdown]
# DOT in docker build . , is build context

# %% [markdown]
# in our terminal we will get sequence of commands

# %% [markdown]
# ##### every little software we install in our container, also gets installed from a container that preexist in the main server of DOCKER

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# here first it took alpine image then created container out of it the ran APK command and updated redus then updated the pervious container, then it ran the CMD redis-server run command

# %% [markdown]
# deep understanding, at every step it updated the previous container, updated it then deleted it then created because the process running becomes the default process therefore deletion was necessary<br>
# after step 2 it created a new image with temporary id and updated the alpine image with Redis program

# %% [markdown]
# ## REBUILD FROM CACHE

# %% [markdown]
# ##### docker build a temporary image at every step and saves it as a temporary image

# %% [markdown]
# ### to run an image

# %% [markdown]
# ##### docker run (image id)

# %% [markdown]
# ### WE CAN GIVE TAG TO A NEWLY BUILT IMAGE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### docker build -t wajeeh/redis:latest . <br> -t is for tag
# it will tag the image with wajeeh/redis:latest

# %% [markdown]
# ### We can create image out of container and also convert container into an image using "docker commit"

# %% [markdown]
# ##### docker commit -c 'CMD ["redis-server"] (container id)<br> -d will assign the default command for the saved image
