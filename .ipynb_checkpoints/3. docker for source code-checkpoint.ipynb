# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### now we do docker build . . <br>which copies all the files from current directory to the container WORKDIR which here is '/app'

# %% [markdown]
# we can tag by using the following command:<br>
# **docker build -t wajeeh/dodgecorona:latest .**

# %% [markdown]
# ## CONNECTING TWO CONTAINERS

# %% [markdown]
# ## DOCKER COMPOSE

# %% [markdown]
# Seperate containers will have seperate connections, we can configure them using **docker-compose**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# docker-compose saves from repetitive commands used in Docker-Cli

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# docker-compose.yml will have different services

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### docker-compose creates in a single container all the defined services

# %% [markdown]
# #### this is how we access redis service from nodejs

# %% [markdown]
# ##### since code and redis are in container, then we can refer to the other container by its host, FOR EG

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we can see the redis-server is the hostname of the redis container

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # docker up

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### NOTE: containers communicate with their hostnames

# %% [markdown]
# ##### docker-container down,,,,,,, to stop the container

# %% [markdown]
# ## TO MAINTAIN AND RESTART CONTAINER

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### To restart the container, we use restart policy in docker-compose

# %% [markdown]
# ![image.png](attachment:image.png)
