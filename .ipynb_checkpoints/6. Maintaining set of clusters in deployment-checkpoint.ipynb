# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # DIFFERENT APPROACHS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### when we are updating, since each pod have a name and type/kind, it will use name to update according to the new config files
# in other words name and kind are the unique id for an object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### if we omit object name then it will give details of all the objeccts of that object type

# %% [markdown]
# if we try to change a pod configuration, we see an error message

# %% [markdown]
# ##### pod allows only limited updation in pods
