# %% [markdown]
# ![Screenshot%20from%202020-07-15%2002-17-59.png](attachment:Screenshot%20from%202020-07-15%2002-17-59.png)

# %% [markdown]
# ![Screenshot%20from%202020-07-15%2002-18-57.png](attachment:Screenshot%20from%202020-07-15%2002-18-57.png)

# %% [markdown]
# ![Screenshot%20from%202020-07-15%2002-20-58.png](attachment:Screenshot%20from%202020-07-15%2002-20-58.png)

# %% [markdown]
# ![Screenshot%20from%202020-07-15%2002-21-51.png](attachment:Screenshot%20from%202020-07-15%2002-21-51.png)

# %% [markdown]
# in above config, we created a service of type NodePort, its targetPort goes to nodejs-port, its a service like expose

# %% [markdown]
# ## note:

# %% [markdown]
# ![Screenshot%20from%202020-07-15%2002-23-21.png](attachment:Screenshot%20from%202020-07-15%2002-23-21.png)

# %% [markdown]
# ![Screenshot%20from%202020-07-15%2002-30-34.png](attachment:Screenshot%20from%202020-07-15%2002-30-34.png)

# %% [markdown]
# in service we defined a port 31001 instead of any random port which kubernetes will assign, apart from that, the selector selects the helloworld app (another pod with defined libel->app: helloworld), and in that pod it both pod will map the ports with each other

# %% [markdown]
# #### to get the url, issue the below command

# %% [markdown]
# ##### kubectl service  (name of the service/NodePort) --url

# %% [markdown]
# ##### we can describe the service as well

# %% [markdown]
# Ip and port will be random unless explicitely defined
