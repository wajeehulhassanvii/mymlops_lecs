# %% [markdown]
# # WHAT IS KUBERNETES

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### BETTER STRATEGY
# this is what KUBERNETES ENABLES:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# in KUBERNETES

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### MASTER CONTROLS WHATS RUNNING IN DIFFERENT NODES

# %% [markdown]
# ## DEVELOPMENT VS PRODUCTION ENVIRONMENT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### ManagedSolutions helps us manage Kubernetes Cluster with different provider

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Kubernetes is orchestration system for docker container
# 1. we can schedule containetrs on cluster of machines
# 2. we can run multiple containers on one machine
# 3. you can run long running services ilke web app
# 4. kubernetes will manage state of the container
#
#     1.can start the container on specific nodes
#     2. will restart a c ontainer when it gets killed
#     3. can move containers from one node to another

# %% [markdown]
# 1. kubernetes manages the containers for us, and we just don't run multiple containers on one host manually
# 2. can start with one node and scale up to 1000s of nodes
# 3. some other popular docker orchestrators are:
#     1. Docker Swarm
#     2. Mesos
#     3. Kubernetes

# %% [markdown]
# Kubernetes works:
# 1. on premise
# 2. on cloud (google, aws, azure)
# 3. hybrid public and private

# %% [markdown]
# highly modular

# %% [markdown]
# ##### Minikube is a tool that allow us to run Kubernetes cluster locally
# cannot spin up production cluster as it does not guarentees high availability
